# %% [markdown]
# A simple function to plot distribution

# %%
# imports
import seaborn as sns
import matplotlib.pyplot as plt

# Configure visualisations
# %matplotlib inline
sns.set_style( 'white' )

# %% [markdown]
# Function takes 3 main arguments
# - df: dataframe to visualise
# - var: x axis values
# - target: y axis values
#
# row and col can be passed in to split data across multiple categories

# %%
def plot_distribution( df , var , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , hue=target , aspect=4 , row = row , col = col )
    facet.map( sns.kdeplot , var , shade= True )
    facet.set( xlim=( 0 , df[ var ].max() ) )
    facet.add_legend()

# %% [markdown]
# Sample:

# %%
import pandas as pd
import numpy as np

y = (pd.Series(np.random.randn(1000)) > 0.5).astype(int)
x = pd.Series(np.random.randn(1000)) * 100

df = pd.DataFrame({'x': x, 'y': y})
plot_distribution( df , var = 'x' , target = 'y' )
# Out:
# /Users/user/anaconda/envs/py35/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
